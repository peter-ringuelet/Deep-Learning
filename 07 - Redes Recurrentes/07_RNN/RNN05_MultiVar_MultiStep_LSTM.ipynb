# %%
ColabNotebook = 'google.colab' in str(get_ipython())

if ColabNotebook:
    # monta G-drive en entorno COLAB
    from google.colab import drive
    drive.mount('/content/drive/')

    DATOS_DIR = '/content/drive/MyDrive/Colab Notebooks/DATOS/'      # carpeta donde se encuentran los datasets
else:
    DATOS_DIR   = './' # carpeta donde se encuentran los datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Leer set de datos
df = pd.read_csv(DATOS_DIR+'weather_dataset_preprocesado.csv', index_col='datetime')
df
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# datetime
# 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78   94.40
# 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77   93.20
# 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66   93.50
# 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02   92.60
# 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65   92.20
# ...                       ...       ...       ...          ...     ...
# 2014-09-24 12:00:00    987.01     13.69    287.92         6.29   60.85
# 2014-09-24 13:00:00    986.55     14.19    288.47         6.80   61.01
# 2014-09-24 14:00:00    986.21     14.99    289.30         6.70   57.54
# 2014-09-24 15:00:00    984.76     15.20    289.63         6.96   57.79
# 2014-09-24 16:00:00    984.61     14.40    288.84         7.00   61.03
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# datetime
# 2009-01-01 01:00:00          3.33          3.14          0.19       1.96
# 2009-01-01 02:00:00          3.12          2.90          0.21       1.81
# 2009-01-01 03:00:00          3.13          2.93          0.20       1.83
# 2009-01-01 04:00:00          3.07          2.85          0.23       1.78
# 2009-01-01 05:00:00          2.94          2.71          0.23       1.69
# ...                           ...           ...           ...        ...
# 2014-09-24 12:00:00         15.69          9.55          6.14       6.04
# 2014-09-24 13:00:00         16.21          9.89          6.32       6.26
# 2014-09-24 14:00:00         17.07          9.82          7.25       6.22
# 2014-09-24 15:00:00         17.30         10.00          7.30       6.34
# 2014-09-24 16:00:00         16.43         10.03          6.40       6.36
#
#                      H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  \
# datetime
# 2009-01-01 01:00:00             3.15       1307.86      0.21           0.63
# 2009-01-01 02:00:00             2.91       1312.25      0.25           0.63
# 2009-01-01 03:00:00             2.94       1312.18      0.18           0.63
# 2009-01-01 04:00:00             2.85       1313.61      0.10           0.38
# 2009-01-01 05:00:00             2.71       1317.19      0.40           0.88
# ...                              ...           ...       ...            ...
# 2014-09-24 12:00:00             9.67       1194.28      2.92           4.00
# 2014-09-24 13:00:00            10.02       1191.48      1.57           2.48
# 2014-09-24 14:00:00             9.96       1187.80      2.79           4.75
# 2014-09-24 15:00:00            10.15       1185.10      2.86           4.32
# 2014-09-24 16:00:00            10.18       1188.20      1.71           2.44
#
#                      wd (deg)
# datetime
# 2009-01-01 01:00:00     192.7
# 2009-01-01 02:00:00     190.3
# 2009-01-01 03:00:00     167.2
# 2009-01-01 04:00:00     240.0
# 2009-01-01 05:00:00     157.0
# ...                       ...
# 2014-09-24 12:00:00     174.1
# 2014-09-24 13:00:00     173.0
# 2014-09-24 14:00:00     202.5
# 2014-09-24 15:00:00     172.0
# 2014-09-24 16:00:00     195.1
#
# [50224 rows x 14 columns]

# %%
# En este caso NO utilizaremos la información de la covariable tiempo

df = df.reset_index()
df = df.drop(columns=['datetime'])
df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        996.50     -8.05    265.38        -8.78   94.40          3.33
# 1        996.62     -8.88    264.54        -9.77   93.20          3.12
# 2        996.84     -8.81    264.59        -9.66   93.50          3.13
# 3        996.99     -9.05    264.34       -10.02   92.60          3.07
# 4        997.46     -9.63    263.72       -10.65   92.20          2.94
# ...         ...       ...       ...          ...     ...           ...
# 50219    987.01     13.69    287.92         6.29   60.85         15.69
# 50220    986.55     14.19    288.47         6.80   61.01         16.21
# 50221    986.21     14.99    289.30         6.70   57.54         17.07
# 50222    984.76     15.20    289.63         6.96   57.79         17.30
# 50223    984.61     14.40    288.84         7.00   61.03         16.43
#
#        VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0              3.14          0.19       1.96             3.15       1307.86
# 1              2.90          0.21       1.81             2.91       1312.25
# 2              2.93          0.20       1.83             2.94       1312.18
# 3              2.85          0.23       1.78             2.85       1313.61
# 4              2.71          0.23       1.69             2.71       1317.19
# ...             ...           ...        ...              ...           ...
# 50219          9.55          6.14       6.04             9.67       1194.28
# 50220          9.89          6.32       6.26            10.02       1191.48
# 50221          9.82          7.25       6.22             9.96       1187.80
# 50222         10.00          7.30       6.34            10.15       1185.10
# 50223         10.03          6.40       6.36            10.18       1188.20
#
#        wv (m/s)  max. wv (m/s)  wd (deg)
# 0          0.21           0.63     192.7
# 1          0.25           0.63     190.3
# 2          0.18           0.63     167.2
# 3          0.10           0.38     240.0
# 4          0.40           0.88     157.0
# ...         ...            ...       ...
# 50219      2.92           4.00     174.1
# 50220      1.57           2.48     173.0
# 50221      2.79           4.75     202.5
# 50222      2.86           4.32     172.0
# 50223      1.71           2.44     195.1
#
# [50224 rows x 14 columns]

# %%
# Ingeniería de características

w_dir = df['wd (deg)']*np.pi/180
Wx = df['wv (m/s)']*np.cos(w_dir)
Wy = df['wv (m/s)']*np.sin(w_dir)

# Eliminar columnas irrelevantes
df.pop('wd (deg)')
df.pop('wv (m/s)')
df.pop('max. wv (m/s)')

#Incluir las nuevas características
df['Wx'] = Wx
df['Wy'] = Wy
df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        996.50     -8.05    265.38        -8.78   94.40          3.33
# 1        996.62     -8.88    264.54        -9.77   93.20          3.12
# 2        996.84     -8.81    264.59        -9.66   93.50          3.13
# 3        996.99     -9.05    264.34       -10.02   92.60          3.07
# 4        997.46     -9.63    263.72       -10.65   92.20          2.94
# ...         ...       ...       ...          ...     ...           ...
# 50219    987.01     13.69    287.92         6.29   60.85         15.69
# 50220    986.55     14.19    288.47         6.80   61.01         16.21
# 50221    986.21     14.99    289.30         6.70   57.54         17.07
# 50222    984.76     15.20    289.63         6.96   57.79         17.30
# 50223    984.61     14.40    288.84         7.00   61.03         16.43
#
#        VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0              3.14          0.19       1.96             3.15       1307.86
# 1              2.90          0.21       1.81             2.91       1312.25
# 2              2.93          0.20       1.83             2.94       1312.18
# 3              2.85          0.23       1.78             2.85       1313.61
# 4              2.71          0.23       1.69             2.71       1317.19
# ...             ...           ...        ...              ...           ...
# 50219          9.55          6.14       6.04             9.67       1194.28
# 50220          9.89          6.32       6.26            10.02       1191.48
# 50221          9.82          7.25       6.22             9.96       1187.80
# 50222         10.00          7.30       6.34            10.15       1185.10
# 50223         10.03          6.40       6.36            10.18       1188.20
#
#              Wx        Wy
# 0     -0.204862 -0.046168
# 1     -0.245971 -0.044701
# 2     -0.175527  0.039879
# 3     -0.050000 -0.086603
# 4     -0.368202  0.156292
# ...         ...       ...
# 50219 -2.904532  0.300154
# 50220 -1.558297  0.191335
# 50221 -2.577624 -1.067687
# 50222 -2.832167  0.398035
# 50223 -1.650958 -0.445463
#
# [50224 rows x 13 columns]

# %%
# Función para generar las particiones preservando las características
# de la serie de tiempo

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):
    # Definir número de datos en cada subserie
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Número de datos de entrenamiento
    Nval = int(vl_size*N)    # Número de datos de validación
    Ntst = N - Ntrain - Nval # Número de datos de prueba

    # Realizar partición
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Prueba de la función
tr, vl, ts = train_val_test_split(df)  #(df['T (degC)'])

print(f'Tamaño set de entrenamiento: {tr.shape}')
print(f'Tamaño set de validación: {vl.shape}')
print(f'Tamaño set de prueba: {ts.shape}')
# Out:
# Tamaño set de entrenamiento: (40179, 13)
# Tamaño set de validación: (5022, 13)
# Tamaño set de prueba: (5023, 13)

# %%
# Dibujemos la temperatura
covar = 1
col = df.columns[covar]

fig, ax = plt.subplots(figsize = (16,5))
ax.plot(tr[col], label='Train')
ax.plot(vl[col], label='Val')
ax.plot(ts[col], label='Test')
plt.legend();

# %%
def crear_dataset_supervisado(array, input_length, col_ref, output_length):
    '''Permite crear un dataset con las entradas (X) y salidas (Y)
    requeridas por la Red SimpleRNN.

    Parámetros:
    - array: arreglo numpy de tamaño N x features (N: cantidad de datos,
      f: cantidad de features)
    - input_length: instantes de tiempo consecutivos de la(s) serie(s) de tiempo
      usados para alimentar el modelo
    - output_length: instantes de tiempo a pronosticar (salida del modelo)
    '''

    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape)==1: # Si tenemos sólo una serie (univariado)
        fils, cols = array.shape[0], 1
        array = array.reshape(fils,cols)
    else: # Multivariado
        fils, cols = array.shape

    # Generar los arreglos
    for i in range(fils-input_length-output_length):
        X.append(array[i:i+INPUT_LENGTH,0:cols])
        Y.append(array[i+input_length:i+input_length+output_length,col_ref].reshape(output_length,1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# %%
# Crear los datasets de entrenamiento, prueba y validación y verificar sus tamaños

col_ref = df.columns.get_loc("T (degC)")   #variable a predecir

INPUT_LENGTH = 24    # Posteriormente afinaremos este hiperparámetro
OUTPUT_LENGTH = 4    # Modelo multi-step

x_tr, y_tr = crear_dataset_supervisado(tr.values, INPUT_LENGTH, col_ref, OUTPUT_LENGTH)
x_vl, y_vl = crear_dataset_supervisado(vl.values, INPUT_LENGTH, col_ref, OUTPUT_LENGTH)
x_ts, y_ts = crear_dataset_supervisado(ts.values, INPUT_LENGTH, col_ref, OUTPUT_LENGTH)

# Imprimir información en pantalla
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (40151, 24, 13), y_tr: (40151, 4, 1)
# Set de validación - x_vl: (4994, 24, 13), y_vl: (4994, 4, 1)
# Set de prueba - x_ts: (4995, 24, 13), y_ts: (4995, 4, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
# atributo a predecir
col_ref = df.columns.get_loc("T (degC)")

NFEATS = x_tr.shape[2]
print("NFEATS = ", NFEATS)
print("col_ref=", col_ref)

#Generar una lista de 'scalers', 1 para cada atributo
scalers = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)]
# Out:
# NFEATS =  13
# col_ref= 1

# %%
# Arreglos que contendrán los datasets escalados
x_tr_s = np.zeros(x_tr.shape)
x_vl_s = np.zeros(x_vl.shape)
x_ts_s = np.zeros(x_ts.shape)
y_tr_s = np.zeros(y_tr.shape)
y_vl_s = np.zeros(y_vl.shape)
y_ts_s = np.zeros(y_ts.shape)

for i in range(NFEATS):
  x_tr_s[:,:,i] = scalers[i].fit_transform(x_tr[:,:,i])
  x_vl_s[:,:,i] = scalers[i].transform(x_vl[:,:,i])
  x_ts_s[:,:,i] = scalers[i].transform(x_ts[:,:,i])

# Escalamiento Ys
y_tr_s[:,:,0] = scalers[col_ref].fit_transform(y_tr[:,:,0])
y_vl_s[:,:,0] = scalers[col_ref].transform(y_vl[:,:,0])
y_ts_s[:,:,0] = scalers[col_ref].transform(y_ts[:,:,0])

# %%
# Gráfica tipo violín para ver la distribución de los valores
fig, ax = plt.subplots(figsize=(12,4))
for i in range(13):
  ax.violinplot(dataset = x_tr_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset = x_vl_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset = x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(13)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale();

# %%
# Observemos la variable temperatura
fig, ax = plt.subplots(figsize=(6,4))
ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())
ax.set_xticks([1])
ax.set_xticklabels(['y (salida)']);

# %%
# Creación del modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf

# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# El modelo

N_UNITS = 128  # Tamaño del estado oculto (h)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 24 (horas) x 13 (feature)

modelo = Sequential()
# modelo.add(SimpleRNN(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' pues queremos pronosticar (regresión)
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               72704
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 73,220
# Trainable params: 73,220
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Pérdida: se usará el RMSE (root mean squared error) para el entrenamiento
# pues permite tener errores en las mismas unidades de la temperatura
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compilación
optimizador = RMSprop(learning_rate=5e-4)
modelo.compile(
    optimizer = optimizador,
    loss=root_mean_squared_error  #loss = 'mse'
)

# Entrenamiento (aproximadamente 1 min usando GPU)
EPOCHS = 80 # Hiperparámetro
BATCH_SIZE = 256 # Hiperparámetro
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# Epoch 1/80
# 157/157 - 12s - loss: 0.0895 - val_loss: 0.0586 - 12s/epoch - 77ms/step
# Epoch 2/80
# 157/157 - 7s - loss: 0.0609 - val_loss: 0.0533 - 7s/epoch - 44ms/step
# Epoch 3/80
# 157/157 - 7s - loss: 0.0558 - val_loss: 0.0498 - 7s/epoch - 45ms/step
# Epoch 4/80
# 157/157 - 7s - loss: 0.0528 - val_loss: 0.0496 - 7s/epoch - 44ms/step
# Epoch 5/80
# 157/157 - 7s - loss: 0.0506 - val_loss: 0.0473 - 7s/epoch - 44ms/step
# Epoch 6/80
# 157/157 - 7s - loss: 0.0489 - val_loss: 0.0439 - 7s/epoch - 48ms/step
# Epoch 7/80
# 157/157 - 7s - loss: 0.0477 - val_loss: 0.0443 - 7s/epoch - 44ms/step
# Epoch 8/80
# 157/157 - 7s - loss: 0.0470 - val_loss: 0.0442 - 7s/epoch - 45ms/step
# Epoch 9/80
# 157/157 - 7s - loss: 0.0465 - val_loss: 0.0438 - 7s/epoch - 45ms/step
# Epoch 10/80
# 157/157 - 7s - loss: 0.0459 - val_loss: 0.0443 - 7s/epoch - 47ms/step
# Epoch 11/80
# 157/157 - 7s - loss: 0.0456 - val_loss: 0.0440 - 7s/epoch - 45ms/step
# Epoch 12/80
# 157/157 - 7s - loss: 0.0452 - val_loss: 0.0426 - 7s/epoch - 45ms/step
# Epoch 13/80
# 157/157 - 7s - loss: 0.0451 - val_loss: 0.0431 - 7s/epoch - 45ms/step
# Epoch 14/80
# 157/157 - 7s - loss: 0.0448 - val_loss: 0.0430 - 7s/epoch - 45ms/step
# Epoch 15/80
# 157/157 - 7s - loss: 0.0446 - val_loss: 0.0422 - 7s/epoch - 46ms/step
# Epoch 16/80
# 157/157 - 7s - loss: 0.0444 - val_loss: 0.0416 - 7s/epoch - 46ms/step
# Epoch 17/80
# 157/157 - 7s - loss: 0.0442 - val_loss: 0.0426 - 7s/epoch - 47ms/step
# Epoch 18/80
# 157/157 - 7s - loss: 0.0440 - val_loss: 0.0410 - 7s/epoch - 46ms/step
# Epoch 19/80
# 157/157 - 8s - loss: 0.0439 - val_loss: 0.0424 - 8s/epoch - 50ms/step
# Epoch 20/80
# 157/157 - 7s - loss: 0.0436 - val_loss: 0.0415 - 7s/epoch - 46ms/step
# Epoch 21/80
# 157/157 - 7s - loss: 0.0434 - val_loss: 0.0432 - 7s/epoch - 46ms/step
# Epoch 22/80
# 157/157 - 7s - loss: 0.0433 - val_loss: 0.0416 - 7s/epoch - 47ms/step
# Epoch 23/80
# 157/157 - 7s - loss: 0.0430 - val_loss: 0.0429 - 7s/epoch - 46ms/step
# Epoch 24/80
# 157/157 - 7s - loss: 0.0430 - val_loss: 0.0432 - 7s/epoch - 46ms/step
# Epoch 25/80
# 157/157 - 7s - loss: 0.0428 - val_loss: 0.0406 - 7s/epoch - 45ms/step
# Epoch 26/80
# 157/157 - 7s - loss: 0.0427 - val_loss: 0.0414 - 7s/epoch - 47ms/step
# Epoch 27/80
# 157/157 - 7s - loss: 0.0425 - val_loss: 0.0406 - 7s/epoch - 46ms/step
# Epoch 28/80
# 157/157 - 7s - loss: 0.0424 - val_loss: 0.0418 - 7s/epoch - 46ms/step
# Epoch 29/80
# 157/157 - 7s - loss: 0.0422 - val_loss: 0.0425 - 7s/epoch - 45ms/step
# Epoch 30/80
# 157/157 - 7s - loss: 0.0421 - val_loss: 0.0409 - 7s/epoch - 47ms/step
# Epoch 31/80
# 157/157 - 7s - loss: 0.0419 - val_loss: 0.0403 - 7s/epoch - 45ms/step
# Epoch 32/80
# 157/157 - 7s - loss: 0.0418 - val_loss: 0.0401 - 7s/epoch - 46ms/step
# Epoch 33/80
# 157/157 - 7s - loss: 0.0418 - val_loss: 0.0414 - 7s/epoch - 46ms/step
# Epoch 34/80
# 157/157 - 7s - loss: 0.0416 - val_loss: 0.0427 - 7s/epoch - 46ms/step
# Epoch 35/80
# 157/157 - 7s - loss: 0.0415 - val_loss: 0.0402 - 7s/epoch - 46ms/step
# Epoch 36/80
# 157/157 - 7s - loss: 0.0414 - val_loss: 0.0413 - 7s/epoch - 46ms/step
# Epoch 37/80
# 157/157 - 7s - loss: 0.0413 - val_loss: 0.0410 - 7s/epoch - 46ms/step
# Epoch 38/80
# 157/157 - 7s - loss: 0.0412 - val_loss: 0.0410 - 7s/epoch - 46ms/step
# Epoch 39/80
# 157/157 - 7s - loss: 0.0411 - val_loss: 0.0405 - 7s/epoch - 46ms/step
# Epoch 40/80
# 157/157 - 7s - loss: 0.0409 - val_loss: 0.0405 - 7s/epoch - 46ms/step
# Epoch 41/80
# 157/157 - 7s - loss: 0.0408 - val_loss: 0.0433 - 7s/epoch - 46ms/step
# Epoch 42/80
# 157/157 - 7s - loss: 0.0408 - val_loss: 0.0408 - 7s/epoch - 48ms/step
# Epoch 43/80
# 157/157 - 7s - loss: 0.0407 - val_loss: 0.0409 - 7s/epoch - 47ms/step
# Epoch 44/80
# 157/157 - 7s - loss: 0.0405 - val_loss: 0.0403 - 7s/epoch - 46ms/step
# Epoch 45/80
# 157/157 - 7s - loss: 0.0404 - val_loss: 0.0436 - 7s/epoch - 46ms/step
# Epoch 46/80
# 157/157 - 7s - loss: 0.0403 - val_loss: 0.0401 - 7s/epoch - 47ms/step
# Epoch 47/80
# 157/157 - 7s - loss: 0.0401 - val_loss: 0.0416 - 7s/epoch - 46ms/step
# Epoch 48/80
# 157/157 - 7s - loss: 0.0401 - val_loss: 0.0415 - 7s/epoch - 47ms/step
# Epoch 49/80
# 157/157 - 7s - loss: 0.0400 - val_loss: 0.0404 - 7s/epoch - 47ms/step
# Epoch 50/80
# 157/157 - 8s - loss: 0.0398 - val_loss: 0.0399 - 8s/epoch - 50ms/step
# Epoch 51/80
# 157/157 - 7s - loss: 0.0398 - val_loss: 0.0401 - 7s/epoch - 47ms/step
# Epoch 52/80
# 157/157 - 8s - loss: 0.0397 - val_loss: 0.0418 - 8s/epoch - 49ms/step
# Epoch 53/80
# 157/157 - 7s - loss: 0.0396 - val_loss: 0.0402 - 7s/epoch - 45ms/step
# Epoch 54/80
# 157/157 - 7s - loss: 0.0395 - val_loss: 0.0410 - 7s/epoch - 46ms/step
# Epoch 55/80
# 157/157 - 7s - loss: 0.0394 - val_loss: 0.0418 - 7s/epoch - 45ms/step
# Epoch 56/80
# 157/157 - 7s - loss: 0.0392 - val_loss: 0.0405 - 7s/epoch - 46ms/step
# Epoch 57/80
# 157/157 - 7s - loss: 0.0391 - val_loss: 0.0405 - 7s/epoch - 46ms/step
# Epoch 58/80
# 157/157 - 7s - loss: 0.0391 - val_loss: 0.0408 - 7s/epoch - 46ms/step
# Epoch 59/80
# 157/157 - 7s - loss: 0.0389 - val_loss: 0.0409 - 7s/epoch - 47ms/step
# Epoch 60/80
# 157/157 - 7s - loss: 0.0387 - val_loss: 0.0414 - 7s/epoch - 47ms/step
# Epoch 61/80
# 157/157 - 7s - loss: 0.0386 - val_loss: 0.0421 - 7s/epoch - 46ms/step
# Epoch 62/80
# 157/157 - 7s - loss: 0.0385 - val_loss: 0.0433 - 7s/epoch - 46ms/step
# Epoch 63/80
# 157/157 - 7s - loss: 0.0384 - val_loss: 0.0404 - 7s/epoch - 47ms/step
# Epoch 64/80
# 157/157 - 7s - loss: 0.0382 - val_loss: 0.0404 - 7s/epoch - 45ms/step
# Epoch 65/80
# 157/157 - 7s - loss: 0.0381 - val_loss: 0.0430 - 7s/epoch - 46ms/step
# Epoch 66/80
# 157/157 - 7s - loss: 0.0379 - val_loss: 0.0412 - 7s/epoch - 46ms/step
# Epoch 67/80
# 157/157 - 7s - loss: 0.0378 - val_loss: 0.0420 - 7s/epoch - 46ms/step
# Epoch 68/80
# 157/157 - 7s - loss: 0.0377 - val_loss: 0.0416 - 7s/epoch - 46ms/step
# Epoch 69/80
# 157/157 - 7s - loss: 0.0375 - val_loss: 0.0420 - 7s/epoch - 46ms/step
# Epoch 70/80
# 157/157 - 7s - loss: 0.0373 - val_loss: 0.0416 - 7s/epoch - 47ms/step
# Epoch 71/80
# 157/157 - 7s - loss: 0.0372 - val_loss: 0.0413 - 7s/epoch - 46ms/step
# Epoch 72/80
# 157/157 - 7s - loss: 0.0370 - val_loss: 0.0421 - 7s/epoch - 46ms/step
# Epoch 73/80
# 157/157 - 7s - loss: 0.0369 - val_loss: 0.0430 - 7s/epoch - 46ms/step
# Epoch 74/80
# 157/157 - 7s - loss: 0.0368 - val_loss: 0.0426 - 7s/epoch - 47ms/step
# Epoch 75/80
# 157/157 - 7s - loss: 0.0366 - val_loss: 0.0431 - 7s/epoch - 47ms/step
# Epoch 76/80
# 157/157 - 7s - loss: 0.0365 - val_loss: 0.0433 - 7s/epoch - 47ms/step
# Epoch 77/80
# 157/157 - 7s - loss: 0.0363 - val_loss: 0.0431 - 7s/epoch - 46ms/step
# Epoch 78/80
# 157/157 - 7s - loss: 0.0362 - val_loss: 0.0437 - 7s/epoch - 46ms/step
# Epoch 79/80
# 157/157 - 7s - loss: 0.0360 - val_loss: 0.0421 - 7s/epoch - 47ms/step
# Epoch 80/80
# 157/157 - 7s - loss: 0.0359 - val_loss: 0.0434 - 7s/epoch - 46ms/step

# %%
 # Graficar curvas de entrenamiento y validación
 # para verificar que no existe overfitting
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Iteración')
plt.ylabel('RMSE')
plt.legend();

# %% [markdown]
# ### Desempeño del modelo

# %%
# Cálculo de MSE para train, val y test
Rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
Rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
Rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Imprimir resultados en pantalla
print('Comparativo desempeños:')
print(f'  MSE train:\t {Rmse_tr:.3f}')
print(f'  MSE val:\t {Rmse_vl:.3f}')
print(f'  MSE test:\t {Rmse_ts:.3f}')
# Out:
# Comparativo desempeños:
#   MSE train:	 0.034
#   MSE val:	 0.042
#   MSE test:	 0.046

# %%
# analizando RMSE en cada una de las 4 predicciones de temperatura
# Calcular predicción sobre el set de prueba escalada en el rango de -1 a 1
y_ts_pred_s = modelo.predict(x_ts_s,verbose=0)

# Llevar la predicción a la escala original
y_ts_pred = scalers[col_ref].inverse_transform(y_ts_pred_s)

# calcular RMSE para cada instante de tiempo predicho
diff_cuad = np.square(y_ts.squeeze()-y_ts_pred)
proms = np.mean(diff_cuad, axis=0) # 1x4
rmse = np.sqrt(proms) # 1x4

#Graficar RMSE
t = np.linspace(1,4,4)

fig,ax = plt.subplots()
ax.scatter(t, rmse)
ax.set_xlabel("Hora predicha")
ax.set_ylabel("Error RMSE (oC)")
plt.xticks(ticks=t, labels=t)
plt.grid();

# %%
def predecir(x, model, scaler):
    '''Genera la predicción de OUTPUT_LENGTH instantes
    de tiempo a futuro con el modelo entrenado.

    Entrada:
    - x: batch (o batches) de datos para ingresar al modelo
      (tamaño: BATCHES X INPUT_LENGTH X FEATURES)
    - model: Red LSTM entrenada
    - scaler: escalador (requerido para llevar la predicción a la escala original)

    Salida:
    - y_pred: la predicción en la escala original (tamaño: BATCHES X OUTPUT_LENGTH X FEATURES)
    '''

    # Calcular predicción escalada en el rango de -1 a 1
    y_pred_s = model.predict(x,verbose=0)

    # Llevar la predicción a la escala original
    y_pred = scaler.inverse_transform(y_pred_s)

    return y_pred.flatten()

# %%
# Calcular predicciones sobre el set de prueba
y_ts_pred = predecir(x_ts_s, modelo, scalers[col_ref])

# %%
N = len(y_ts_pred)    # Número de predicciones
ndato = np.linspace(1,N,N)

# Cálculo de errores simples
errores = y_ts.flatten()-y_ts_pred
plt.plot(errores);
