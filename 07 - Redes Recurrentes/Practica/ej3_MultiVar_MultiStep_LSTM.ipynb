# %% [markdown]
# ## Configuro notebook

# %%
# configuración para notebook con instalación LOCAL
FUENTES_DIR  = '../../Datos-Fuentes/Fuentes/'     # carpeta donde se encuentran archivos .py auxiliares
DATOS_DIR    = '../../Datos-Fuentes/Datos/'      # carpeta donde se encuentran los datasets
MODELOS_DIR  = '../Modelos/'    # carpeta donde se encuentran los modelos
ARCHIVOs_DIR = '../Archivos/'   # carpeta recuperar o copiar archivos

# agrega ruta de busqueda donde tenemos archivos .py
import sys
sys.path.append(FUENTES_DIR)

# %% [markdown]
# ## Importo librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ## Preparo dataset

# %%
df = pd.read_csv(DATOS_DIR+'beijing_air_quality.csv')
display(df.head())
# Out:
#       No  PM2.5   PM10   SO2    NO2      CO   O3  TEMP    PRES  DEWP  RAIN  \
# 0  16151  118.0  147.0  58.0  100.0  2000.0  2.0  -5.0  1021.0 -17.2   0.0
# 1  16152  137.0  179.0  63.0  101.0  2100.0  2.0  -6.0  1018.0 -14.3   0.0
# 2  16153  141.0  215.0  59.0  100.0  2300.0  2.0  -7.0  1016.0 -15.9   0.0
# 3  16154  136.0  158.0  65.0  106.0  3000.0  2.0  -7.0  1016.0 -12.7   0.0
# 4  16155  132.0  163.0  56.0  107.0  3000.0  2.0  -6.0  1014.0 -16.9   0.0
#
#     wd  WSPM       station             datetime
# 0   SW   0.7  Aotizhongxin  2015-01-02 22:00:00
# 1  NNW   0.7  Aotizhongxin  2015-01-02 23:00:00
# 2  SSE   0.4  Aotizhongxin  2015-01-03 00:00:00
# 3  ESE   0.4  Aotizhongxin  2015-01-03 01:00:00
# 4   NE   1.1  Aotizhongxin  2015-01-03 02:00:00

# %%
df=df.drop(columns=['RAIN', 'wd', 'No', 'station'])
print(df.shape)
display(df.head())
# Out:
# (18914, 11)
#    PM2.5   PM10   SO2    NO2      CO   O3  TEMP    PRES  DEWP  WSPM  \
# 0  118.0  147.0  58.0  100.0  2000.0  2.0  -5.0  1021.0 -17.2   0.7
# 1  137.0  179.0  63.0  101.0  2100.0  2.0  -6.0  1018.0 -14.3   0.7
# 2  141.0  215.0  59.0  100.0  2300.0  2.0  -7.0  1016.0 -15.9   0.4
# 3  136.0  158.0  65.0  106.0  3000.0  2.0  -7.0  1016.0 -12.7   0.4
# 4  132.0  163.0  56.0  107.0  3000.0  2.0  -6.0  1014.0 -16.9   1.1
#
#               datetime
# 0  2015-01-02 22:00:00
# 1  2015-01-02 23:00:00
# 2  2015-01-03 00:00:00
# 3  2015-01-03 01:00:00
# 4  2015-01-03 02:00:00

# %%
import datetime

timestamp_s = pd.to_datetime(df.datetime).map(datetime.datetime.timestamp)

fft = tf.signal.rfft(df['NO2'])
f_per_dataset = np.arange(0, len(fft))

n_sample_h = len(df['NO2'])
hours_per_week = 24 * 7
weeks_per_dataset = n_sample_h / hours_per_week

f_per_week = f_per_dataset / weeks_per_dataset

plt.step(f_per_week, np.abs(fft))
plt.xscale('log')
plt.xticks([1, 7], ['1/week', '1/day'])
plt.xlabel('Frequency')
plt.tight_layout()
plt.show()

# %%
df = df.drop(['datetime'], axis=1)

df.head()
# Out:
#    PM2.5   PM10   SO2    NO2      CO   O3  TEMP    PRES  DEWP  WSPM
# 0  118.0  147.0  58.0  100.0  2000.0  2.0  -5.0  1021.0 -17.2   0.7
# 1  137.0  179.0  63.0  101.0  2100.0  2.0  -6.0  1018.0 -14.3   0.7
# 2  141.0  215.0  59.0  100.0  2300.0  2.0  -7.0  1016.0 -15.9   0.4
# 3  136.0  158.0  65.0  106.0  3000.0  2.0  -7.0  1016.0 -12.7   0.4
# 4  132.0  163.0  56.0  107.0  3000.0  2.0  -6.0  1014.0 -16.9   1.1

# %%
print(df.corr())
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3      TEMP  \
# PM2.5  1.000000  0.885525  0.486366  0.707551  0.777983 -0.187513 -0.174947
# PM10   0.885525  1.000000  0.461968  0.647914  0.672198 -0.149632 -0.138423
# SO2    0.486366  0.461968  1.000000  0.437755  0.512802 -0.198206 -0.384969
# NO2    0.707551  0.647914  0.437755  1.000000  0.716804 -0.520762 -0.304801
# CO     0.777983  0.672198  0.512802  0.716804  1.000000 -0.348935 -0.368847
# O3    -0.187513 -0.149632 -0.198206 -0.520762 -0.348935  1.000000  0.621334
# TEMP  -0.174947 -0.138423 -0.384969 -0.304801 -0.368847  0.621334  1.000000
# PRES   0.014056 -0.027557  0.223439  0.149588  0.200579 -0.461327 -0.839829
# DEWP   0.082099  0.036170 -0.322258  0.010929 -0.078324  0.318139  0.821227
# WSPM  -0.307466 -0.205875 -0.160812 -0.516863 -0.343894  0.370154  0.087240
#
#            PRES      DEWP      WSPM
# PM2.5  0.014056  0.082099 -0.307466
# PM10  -0.027557  0.036170 -0.205875
# SO2    0.223439 -0.322258 -0.160812
# NO2    0.149588  0.010929 -0.516863
# CO     0.200579 -0.078324 -0.343894
# O3    -0.461327  0.318139  0.370154
# TEMP  -0.839829  0.821227  0.087240
# PRES   1.000000 -0.769310  0.009816
# DEWP  -0.769310  1.000000 -0.243142
# WSPM   0.009816 -0.243142  1.000000

# %%
df = df.drop(['TEMP', 'PRES', 'DEWP'], axis=1)

df.head()
# Out:
#    PM2.5   PM10   SO2    NO2      CO   O3  WSPM
# 0  118.0  147.0  58.0  100.0  2000.0  2.0   0.7
# 1  137.0  179.0  63.0  101.0  2100.0  2.0   0.7
# 2  141.0  215.0  59.0  100.0  2300.0  2.0   0.4
# 3  136.0  158.0  65.0  106.0  3000.0  2.0   0.4
# 4  132.0  163.0  56.0  107.0  3000.0  2.0   1.1

# %% [markdown]
# # Función para generar las particiones preservando las características de la serie de tiempo

# %%
def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):
    # Definir número de datos en cada subserie
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Número de datos de entrenamiento
    Nval = int(vl_size*N)    # Número de datos de validación
    Ntst = N - Ntrain - Nval # Número de datos de prueba

    # Realizar partición
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Prueba de la función
tr, vl, ts = train_val_test_split(df)

print(f'Tamaño set de entrenamiento: {tr.shape}')
print(f'Tamaño set de validación: {vl.shape}')
print(f'Tamaño set de prueba: {ts.shape}')
# Out:
# Tamaño set de entrenamiento: (15131, 7)
# Tamaño set de validación: (1891, 7)
# Tamaño set de prueba: (1892, 7)

# %% [markdown]
# # Dibujo la temperatura

# %%
covar = 3
col = df.columns[covar]

fig, ax = plt.subplots(figsize = (16,5))
ax.plot(tr.iloc[12000:-1,covar], label='Train')
ax.plot(vl[col], label='Val')
ax.plot(ts[col], label='Test')
plt.legend();

# %%
def crear_dataset_supervisado(array, input_length, output_length):
    '''Permite crear un dataset con las entradas (X) y salidas (Y)
    requeridas por la Red SimpleRNN.

    Parámetros:
    - array: arreglo numpy de tamaño N x features (N: cantidad de datos,
      f: cantidad de features)
    - input_length: instantes de tiempo consecutivos de la(s) serie(s) de tiempo
      usados para alimentar el modelo
    - output_length: instantes de tiempo a pronosticar (salida del modelo)
    '''

    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape)==1: # Si tenemos sólo una serie (univariado)
        fils, cols = array.shape[0], 1
        array = array.reshape(fils,cols)
    else: # Multivariado
        fils, cols = array.shape

    # Generar los arreglos
    for i in range(fils-input_length-output_length):
        X.append(array[i:i+input_length,0:cols])
        Y.append(array[i+input_length:i+input_length+output_length,-1].reshape(output_length,1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# %% [markdown]
# # Crear los datasets de entrenamiento, prueba y validación y verificar sus tamaños

# %%
INPUT_LENGTH = 24    # Posteriormente afinaremos este hiperparámetro
OUTPUT_LENGTH = 4    # Modelo uni-step

x_tr, y_tr = crear_dataset_supervisado(tr.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_vl, y_vl = crear_dataset_supervisado(vl.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_ts, y_ts = crear_dataset_supervisado(ts.values, INPUT_LENGTH, OUTPUT_LENGTH)

# Imprimir información en pantalla
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (15103, 24, 7), y_tr: (15103, 4, 1)
# Set de validación - x_vl: (1863, 24, 7), y_vl: (1863, 4, 1)
# Set de prueba - x_ts: (1864, 24, 7), y_ts: (1864, 4, 1)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
# atributo a predecir
col_ref = df.columns.get_loc("NO2")

NFEATS = x_tr.shape[2]
print("NFEATS = ", NFEATS)
print("col_ref=", col_ref)

#Generar una lista de 'scalers', 1 para cada atributo
#scalers = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)]
scalers = [MinMaxScaler(feature_range=(0,1)) for i in range(NFEATS)]
#scalers = [RobustScaler() for i in range(NFEATS)]
#scalers = [StandardScaler() for i in range(NFEATS)]
# Out:
# NFEATS =  7
# col_ref= 3

# %%
# Arreglos que contendrán los datasets escalados
x_tr_s = np.zeros(x_tr.shape)
x_vl_s = np.zeros(x_vl.shape)
x_ts_s = np.zeros(x_ts.shape)
y_tr_s = np.zeros(y_tr.shape)
y_vl_s = np.zeros(y_vl.shape)
y_ts_s = np.zeros(y_ts.shape)

for i in range(NFEATS):
  x_tr_s[:,:,i] = scalers[i].fit_transform(x_tr[:,:,i])
  x_vl_s[:,:,i] = scalers[i].transform(x_vl[:,:,i])
  x_ts_s[:,:,i] = scalers[i].transform(x_ts[:,:,i])

# Escalamiento Ys
y_tr_s[:,:,0] = scalers[col_ref].fit_transform(y_tr[:,:,0])
y_vl_s[:,:,0] = scalers[col_ref].transform(y_vl[:,:,0])
y_ts_s[:,:,0] = scalers[col_ref].transform(y_ts[:,:,0])

# %% [markdown]
# # Gráfica tipo violín para ver la distribución de los valores

# %%
fig, ax = plt.subplots(figsize=(12,4))
for i in range(NFEATS):
  ax.violinplot(dataset = x_tr_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset = x_vl_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset = x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale();

# %% [markdown]
# # Observemos la variable temperatura

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())
ax.set_xticks([1])
ax.set_xticklabels(['y (salida)']);

# %% [markdown]
# # Creación del modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf

# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# El modelo

N_UNITS = 128  # Tamaño del estado oculto (h)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 24 (horas) x 13 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE)) #, return_sequences=True))
#modelo.add(LSTM(64))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' pues queremos pronosticar (regresión)
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               69632
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 70,148
# Trainable params: 70,148
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Pérdida: se usará el RMSE (root mean squared error) para el entrenamiento
# pues permite tener errores en las mismas unidades de la temperatura
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compilación
optimizador = RMSprop(learning_rate=5e-4)
modelo.compile(
    optimizer = optimizador,
    loss=root_mean_squared_error  #loss = 'mse'
)

# Entrenamiento (aproximadamente 1 min usando GPU)
EPOCHS = 80 # Hiperparámetro
BATCH_SIZE = 256 # Hiperparámetro
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# Epoch 1/80
# 59/59 - 2s - loss: 0.1029 - val_loss: 0.0840 - 2s/epoch - 30ms/step
# Epoch 2/80
# 59/59 - 0s - loss: 0.0897 - val_loss: 0.0885 - 316ms/epoch - 5ms/step
# Epoch 3/80
# 59/59 - 0s - loss: 0.0858 - val_loss: 0.0772 - 313ms/epoch - 5ms/step
# Epoch 4/80
# 59/59 - 0s - loss: 0.0839 - val_loss: 0.0796 - 317ms/epoch - 5ms/step
# Epoch 5/80
# 59/59 - 0s - loss: 0.0821 - val_loss: 0.0748 - 320ms/epoch - 5ms/step
# Epoch 6/80
# 59/59 - 0s - loss: 0.0810 - val_loss: 0.0751 - 303ms/epoch - 5ms/step
# Epoch 7/80
# 59/59 - 0s - loss: 0.0801 - val_loss: 0.0754 - 306ms/epoch - 5ms/step
# Epoch 8/80
# 59/59 - 0s - loss: 0.0793 - val_loss: 0.0779 - 302ms/epoch - 5ms/step
# Epoch 9/80
# 59/59 - 0s - loss: 0.0785 - val_loss: 0.0719 - 303ms/epoch - 5ms/step
# Epoch 10/80
# 59/59 - 0s - loss: 0.0780 - val_loss: 0.0715 - 394ms/epoch - 7ms/step
# Epoch 11/80
# 59/59 - 0s - loss: 0.0774 - val_loss: 0.0708 - 342ms/epoch - 6ms/step
# Epoch 12/80
# 59/59 - 0s - loss: 0.0770 - val_loss: 0.0724 - 364ms/epoch - 6ms/step
# Epoch 13/80
# 59/59 - 0s - loss: 0.0767 - val_loss: 0.0708 - 275ms/epoch - 5ms/step
# Epoch 14/80
# 59/59 - 0s - loss: 0.0764 - val_loss: 0.0712 - 249ms/epoch - 4ms/step
# Epoch 15/80
# 59/59 - 0s - loss: 0.0762 - val_loss: 0.0730 - 235ms/epoch - 4ms/step
# Epoch 16/80
# 59/59 - 0s - loss: 0.0762 - val_loss: 0.0727 - 285ms/epoch - 5ms/step
# Epoch 17/80
# 59/59 - 0s - loss: 0.0759 - val_loss: 0.0738 - 256ms/epoch - 4ms/step
# Epoch 18/80
# 59/59 - 0s - loss: 0.0758 - val_loss: 0.0716 - 244ms/epoch - 4ms/step
# Epoch 19/80
# 59/59 - 0s - loss: 0.0756 - val_loss: 0.0703 - 240ms/epoch - 4ms/step
# Epoch 20/80
# 59/59 - 0s - loss: 0.0756 - val_loss: 0.0736 - 246ms/epoch - 4ms/step
# Epoch 21/80
# 59/59 - 0s - loss: 0.0754 - val_loss: 0.0719 - 245ms/epoch - 4ms/step
# Epoch 22/80
# 59/59 - 0s - loss: 0.0754 - val_loss: 0.0709 - 239ms/epoch - 4ms/step
# Epoch 23/80
# 59/59 - 0s - loss: 0.0752 - val_loss: 0.0715 - 292ms/epoch - 5ms/step
# Epoch 24/80
# 59/59 - 0s - loss: 0.0753 - val_loss: 0.0711 - 243ms/epoch - 4ms/step
# Epoch 25/80
# 59/59 - 0s - loss: 0.0752 - val_loss: 0.0722 - 241ms/epoch - 4ms/step
# Epoch 26/80
# 59/59 - 0s - loss: 0.0750 - val_loss: 0.0709 - 270ms/epoch - 5ms/step
# Epoch 27/80
# 59/59 - 0s - loss: 0.0751 - val_loss: 0.0711 - 237ms/epoch - 4ms/step
# Epoch 28/80
# 59/59 - 0s - loss: 0.0749 - val_loss: 0.0736 - 312ms/epoch - 5ms/step
# Epoch 29/80
# 59/59 - 0s - loss: 0.0750 - val_loss: 0.0708 - 303ms/epoch - 5ms/step
# Epoch 30/80
# 59/59 - 0s - loss: 0.0749 - val_loss: 0.0717 - 296ms/epoch - 5ms/step
# Epoch 31/80
# 59/59 - 0s - loss: 0.0748 - val_loss: 0.0713 - 258ms/epoch - 4ms/step
# Epoch 32/80
# 59/59 - 0s - loss: 0.0747 - val_loss: 0.0711 - 344ms/epoch - 6ms/step
# Epoch 33/80
# 59/59 - 0s - loss: 0.0747 - val_loss: 0.0733 - 312ms/epoch - 5ms/step
# Epoch 34/80
# 59/59 - 0s - loss: 0.0746 - val_loss: 0.0725 - 299ms/epoch - 5ms/step
# Epoch 35/80
# 59/59 - 0s - loss: 0.0745 - val_loss: 0.0713 - 329ms/epoch - 6ms/step
# Epoch 36/80
# 59/59 - 0s - loss: 0.0744 - val_loss: 0.0716 - 295ms/epoch - 5ms/step
# Epoch 37/80
# 59/59 - 0s - loss: 0.0745 - val_loss: 0.0732 - 294ms/epoch - 5ms/step
# Epoch 38/80
# 59/59 - 0s - loss: 0.0744 - val_loss: 0.0714 - 306ms/epoch - 5ms/step
# Epoch 39/80
# 59/59 - 0s - loss: 0.0744 - val_loss: 0.0732 - 303ms/epoch - 5ms/step
# Epoch 40/80
# 59/59 - 0s - loss: 0.0742 - val_loss: 0.0741 - 300ms/epoch - 5ms/step
# Epoch 41/80
# 59/59 - 0s - loss: 0.0743 - val_loss: 0.0722 - 295ms/epoch - 5ms/step
# Epoch 42/80
# 59/59 - 0s - loss: 0.0743 - val_loss: 0.0734 - 293ms/epoch - 5ms/step
# Epoch 43/80
# 59/59 - 0s - loss: 0.0741 - val_loss: 0.0734 - 307ms/epoch - 5ms/step
# Epoch 44/80
# 59/59 - 0s - loss: 0.0740 - val_loss: 0.0713 - 299ms/epoch - 5ms/step
# Epoch 45/80
# 59/59 - 0s - loss: 0.0740 - val_loss: 0.0737 - 297ms/epoch - 5ms/step
# Epoch 46/80
# 59/59 - 0s - loss: 0.0740 - val_loss: 0.0718 - 299ms/epoch - 5ms/step
# Epoch 47/80
# 59/59 - 0s - loss: 0.0739 - val_loss: 0.0735 - 294ms/epoch - 5ms/step
# Epoch 48/80
# 59/59 - 0s - loss: 0.0738 - val_loss: 0.0718 - 297ms/epoch - 5ms/step
# Epoch 49/80
# 59/59 - 0s - loss: 0.0738 - val_loss: 0.0721 - 293ms/epoch - 5ms/step
# Epoch 50/80
# 59/59 - 0s - loss: 0.0736 - val_loss: 0.0720 - 294ms/epoch - 5ms/step
# Epoch 51/80
# 59/59 - 0s - loss: 0.0737 - val_loss: 0.0724 - 294ms/epoch - 5ms/step
# Epoch 52/80
# 59/59 - 0s - loss: 0.0735 - val_loss: 0.0717 - 301ms/epoch - 5ms/step
# Epoch 53/80
# 59/59 - 0s - loss: 0.0734 - val_loss: 0.0724 - 306ms/epoch - 5ms/step
# Epoch 54/80
# 59/59 - 0s - loss: 0.0734 - val_loss: 0.0731 - 301ms/epoch - 5ms/step
# Epoch 55/80
# 59/59 - 0s - loss: 0.0734 - val_loss: 0.0717 - 309ms/epoch - 5ms/step
# Epoch 56/80
# 59/59 - 0s - loss: 0.0732 - val_loss: 0.0727 - 303ms/epoch - 5ms/step
# Epoch 57/80
# 59/59 - 0s - loss: 0.0732 - val_loss: 0.0712 - 298ms/epoch - 5ms/step
# Epoch 58/80
# 59/59 - 0s - loss: 0.0732 - val_loss: 0.0752 - 304ms/epoch - 5ms/step
# Epoch 59/80
# 59/59 - 0s - loss: 0.0731 - val_loss: 0.0745 - 300ms/epoch - 5ms/step
# Epoch 60/80
# 59/59 - 0s - loss: 0.0731 - val_loss: 0.0726 - 301ms/epoch - 5ms/step
# Epoch 61/80
# 59/59 - 0s - loss: 0.0730 - val_loss: 0.0743 - 300ms/epoch - 5ms/step
# Epoch 62/80
# 59/59 - 0s - loss: 0.0728 - val_loss: 0.0710 - 299ms/epoch - 5ms/step
# Epoch 63/80
# 59/59 - 0s - loss: 0.0729 - val_loss: 0.0726 - 292ms/epoch - 5ms/step
# Epoch 64/80
# 59/59 - 0s - loss: 0.0727 - val_loss: 0.0718 - 304ms/epoch - 5ms/step
# Epoch 65/80
# 59/59 - 0s - loss: 0.0726 - val_loss: 0.0744 - 303ms/epoch - 5ms/step
# Epoch 66/80
# 59/59 - 0s - loss: 0.0726 - val_loss: 0.0720 - 303ms/epoch - 5ms/step
# Epoch 67/80
# 59/59 - 0s - loss: 0.0724 - val_loss: 0.0733 - 303ms/epoch - 5ms/step
# Epoch 68/80
# 59/59 - 0s - loss: 0.0726 - val_loss: 0.0724 - 330ms/epoch - 6ms/step
# Epoch 69/80
# 59/59 - 0s - loss: 0.0723 - val_loss: 0.0730 - 284ms/epoch - 5ms/step
# Epoch 70/80
# 59/59 - 0s - loss: 0.0722 - val_loss: 0.0711 - 282ms/epoch - 5ms/step
# Epoch 71/80
# 59/59 - 0s - loss: 0.0722 - val_loss: 0.0726 - 287ms/epoch - 5ms/step
# Epoch 72/80
# 59/59 - 0s - loss: 0.0722 - val_loss: 0.0709 - 285ms/epoch - 5ms/step
# Epoch 73/80
# 59/59 - 0s - loss: 0.0721 - val_loss: 0.0724 - 282ms/epoch - 5ms/step
# Epoch 74/80
# 59/59 - 0s - loss: 0.0719 - val_loss: 0.0730 - 279ms/epoch - 5ms/step
# Epoch 75/80
# 59/59 - 0s - loss: 0.0718 - val_loss: 0.0717 - 282ms/epoch - 5ms/step
# Epoch 76/80
# 59/59 - 0s - loss: 0.0719 - val_loss: 0.0736 - 279ms/epoch - 5ms/step
# Epoch 77/80
# 59/59 - 0s - loss: 0.0718 - val_loss: 0.0730 - 281ms/epoch - 5ms/step
# Epoch 78/80
# 59/59 - 0s - loss: 0.0715 - val_loss: 0.0720 - 282ms/epoch - 5ms/step
# Epoch 79/80
# 59/59 - 0s - loss: 0.0715 - val_loss: 0.0745 - 297ms/epoch - 5ms/step
# Epoch 80/80
# 59/59 - 0s - loss: 0.0714 - val_loss: 0.0733 - 282ms/epoch - 5ms/step

# %% [markdown]
# ## Graficar curvas de entrenamiento y validación para verificar que no existe overfitting

# %%
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Iteración')
plt.ylabel('RMSE')
plt.legend();

# %% [markdown]
# ## Desempeño del modelo

# %%
# Cálculo de MSE para train, val y test
Rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
Rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
Rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Imprimir resultados en pantalla
print('Comparativo desempeños:')
print(f'  MSE train:\t {Rmse_tr:.3f}')
print(f'  MSE val:\t {Rmse_vl:.3f}')
print(f'  MSE test:\t {Rmse_ts:.3f}')
# Out:
# Comparativo desempeños:
#   MSE train:	 0.067
#   MSE val:	 0.070
#   MSE test:	 0.074

# %%
def predecir(x, model, scaler):
    '''Genera la predicción de OUTPUT_LENGTH instantes
    de tiempo a futuro con el modelo entrenado.

    Entrada:
    - x: batch (o batches) de datos para ingresar al modelo
      (tamaño: BATCHES X INPUT_LENGTH X FEATURES)
    - model: Red LSTM entrenada
    - scaler: escalador (requerido para llevar la predicción a la escala original)

    Salida:
    - y_pred: la predicción en la escala original (tamaño: BATCHES X OUTPUT_LENGTH X FEATURES)
    '''

    # Calcular predicción escalada en el rango de -1 a 1
    y_pred_s = model.predict(x,verbose=0)

    # Llevar la predicción a la escala original
    y_pred = scaler.inverse_transform(y_pred_s)

    return y_pred.flatten()

# %% [markdown]
# ## Calcular predicciones sobre el set de prueba

# %%
y_ts_pred = predecir(x_ts_s, modelo, scalers[col_ref])

# %%
N = len(y_ts_pred)    # Número de predicciones
ndato = np.linspace(1,N,N)

# Cálculo de errores simples
errores = y_ts.flatten()-y_ts_pred
plt.plot(errores);

# %%
# Dibujemos los subsets
fig, ax = plt.subplots(figsize = (16,5))
ax.plot(y_ts.flatten()[:200], label='True')
ax.plot(y_ts_pred[:200], label='Predice')
plt.legend();

# %%
model = Sequential([

                              LSTM(50, input_shape=(10, 1)),

                              Dense(1)

                         ])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 50)                10400
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________
