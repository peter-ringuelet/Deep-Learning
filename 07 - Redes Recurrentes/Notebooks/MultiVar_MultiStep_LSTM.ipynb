# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
# Leer set de datos
ruta = '/content/drive/MyDrive/Colab Notebooks/DATOS/'
df = pd.read_csv(ruta+'beijing_air_quality.csv')
df
# Out:
#           No  PM2.5   PM10   SO2    NO2      CO    O3  TEMP    PRES  DEWP  \
# 0      16151  118.0  147.0  58.0  100.0  2000.0   2.0  -5.0  1021.0 -17.2
# 1      16152  137.0  179.0  63.0  101.0  2100.0   2.0  -6.0  1018.0 -14.3
# 2      16153  141.0  215.0  59.0  100.0  2300.0   2.0  -7.0  1016.0 -15.9
# 3      16154  136.0  158.0  65.0  106.0  3000.0   2.0  -7.0  1016.0 -12.7
# 4      16155  132.0  163.0  56.0  107.0  3000.0   2.0  -6.0  1014.0 -16.9
# ...      ...    ...    ...   ...    ...     ...   ...   ...     ...   ...
# 18909  35060   12.0   29.0   5.0   35.0   400.0  95.0  12.5  1013.5 -16.2
# 18910  35061   13.0   37.0   7.0   45.0   500.0  81.0  11.6  1013.6 -15.1
# 18911  35062   16.0   37.0  10.0   66.0   700.0  58.0  10.8  1014.2 -13.3
# 18912  35063   21.0   44.0  12.0   87.0   700.0  35.0  10.5  1014.4 -12.9
# 18913  35064   19.0   31.0  10.0   79.0   600.0  42.0   8.6  1014.1 -15.9
#
#        RAIN   wd  WSPM       station             datetime
# 0       0.0   SW   0.7  Aotizhongxin  2015-01-02 22:00:00
# 1       0.0  NNW   0.7  Aotizhongxin  2015-01-02 23:00:00
# 2       0.0  SSE   0.4  Aotizhongxin  2015-01-03 00:00:00
# 3       0.0  ESE   0.4  Aotizhongxin  2015-01-03 01:00:00
# 4       0.0   NE   1.1  Aotizhongxin  2015-01-03 02:00:00
# ...     ...  ...   ...           ...                  ...
# 18909   0.0   NW   2.4  Aotizhongxin  2017-02-28 19:00:00
# 18910   0.0  WNW   0.9  Aotizhongxin  2017-02-28 20:00:00
# 18911   0.0   NW   1.1  Aotizhongxin  2017-02-28 21:00:00
# 18912   0.0  NNW   1.2  Aotizhongxin  2017-02-28 22:00:00
# 18913   0.0  NNE   1.3  Aotizhongxin  2017-02-28 23:00:00
#
# [18914 rows x 15 columns]

# %%
df=df.drop(columns=['RAIN', 'wd', 'No', 'station', 'datetime'])

print(df.shape)
# Out:
# (18914, 10)

# %%
df.head()
# Out:
#    PM2.5   PM10   SO2    NO2      CO   O3  TEMP    PRES  DEWP  WSPM
# 0  118.0  147.0  58.0  100.0  2000.0  2.0  -5.0  1021.0 -17.2   0.7
# 1  137.0  179.0  63.0  101.0  2100.0  2.0  -6.0  1018.0 -14.3   0.7
# 2  141.0  215.0  59.0  100.0  2300.0  2.0  -7.0  1016.0 -15.9   0.4
# 3  136.0  158.0  65.0  106.0  3000.0  2.0  -7.0  1016.0 -12.7   0.4
# 4  132.0  163.0  56.0  107.0  3000.0  2.0  -6.0  1014.0 -16.9   1.1

# %%
print(df.corr())
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3      TEMP  \
# PM2.5  1.000000  0.885525  0.486366  0.707551  0.777983 -0.187513 -0.174947
# PM10   0.885525  1.000000  0.461968  0.647914  0.672198 -0.149632 -0.138423
# SO2    0.486366  0.461968  1.000000  0.437755  0.512802 -0.198206 -0.384969
# NO2    0.707551  0.647914  0.437755  1.000000  0.716804 -0.520762 -0.304801
# CO     0.777983  0.672198  0.512802  0.716804  1.000000 -0.348935 -0.368847
# O3    -0.187513 -0.149632 -0.198206 -0.520762 -0.348935  1.000000  0.621334
# TEMP  -0.174947 -0.138423 -0.384969 -0.304801 -0.368847  0.621334  1.000000
# PRES   0.014056 -0.027557  0.223439  0.149588  0.200579 -0.461327 -0.839829
# DEWP   0.082099  0.036170 -0.322258  0.010929 -0.078324  0.318139  0.821227
# WSPM  -0.307466 -0.205875 -0.160812 -0.516863 -0.343894  0.370154  0.087240
#
#            PRES      DEWP      WSPM
# PM2.5  0.014056  0.082099 -0.307466
# PM10  -0.027557  0.036170 -0.205875
# SO2    0.223439 -0.322258 -0.160812
# NO2    0.149588  0.010929 -0.516863
# CO     0.200579 -0.078324 -0.343894
# O3    -0.461327  0.318139  0.370154
# TEMP  -0.839829  0.821227  0.087240
# PRES   1.000000 -0.769310  0.009816
# DEWP  -0.769310  1.000000 -0.243142
# WSPM   0.009816 -0.243142  1.000000

# %%
df = df.drop(['TEMP', 'PRES', 'DEWP'], axis=1)

df.head()
# Out:
#    PM2.5   PM10   SO2    NO2      CO   O3  WSPM
# 0  118.0  147.0  58.0  100.0  2000.0  2.0   0.7
# 1  137.0  179.0  63.0  101.0  2100.0  2.0   0.7
# 2  141.0  215.0  59.0  100.0  2300.0  2.0   0.4
# 3  136.0  158.0  65.0  106.0  3000.0  2.0   0.4
# 4  132.0  163.0  56.0  107.0  3000.0  2.0   1.1

# %%
# Función para generar las particiones preservando las características
# de la serie de tiempo

def train_val_test_split(serie, tr_size=0.8, vl_size=0.1, ts_size=0.1 ):
    # Definir número de datos en cada subserie
    N = serie.shape[0]
    Ntrain = int(tr_size*N)  # Número de datos de entrenamiento
    Nval = int(vl_size*N)    # Número de datos de validación
    Ntst = N - Ntrain - Nval # Número de datos de prueba

    # Realizar partición
    train = serie[0:Ntrain]
    val = serie[Ntrain:Ntrain+Nval]
    test = serie[Ntrain+Nval:]

    return train, val, test

# Prueba de la función
tr, vl, ts = train_val_test_split(df)

print(f'Tamaño set de entrenamiento: {tr.shape}')
print(f'Tamaño set de validación: {vl.shape}')
print(f'Tamaño set de prueba: {ts.shape}')
# Out:
# Tamaño set de entrenamiento: (15131, 7)
# Tamaño set de validación: (1891, 7)
# Tamaño set de prueba: (1892, 7)

# %%
# Dibujemos la temperatura
covar = 3
col = df.columns[covar]

fig, ax = plt.subplots(figsize = (16,5))
ax.plot(tr.iloc[12000:-1,covar], label='Train')
ax.plot(vl[col], label='Val')
ax.plot(ts[col], label='Test')
plt.legend();

# %%
def crear_dataset_supervisado(array, input_length, output_length):
    '''Permite crear un dataset con las entradas (X) y salidas (Y)
    requeridas por la Red SimpleRNN.

    Parámetros:
    - array: arreglo numpy de tamaño N x features (N: cantidad de datos,
      f: cantidad de features)
    - input_length: instantes de tiempo consecutivos de la(s) serie(s) de tiempo
      usados para alimentar el modelo
    - output_length: instantes de tiempo a pronosticar (salida del modelo)
    '''

    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape)==1: # Si tenemos sólo una serie (univariado)
        fils, cols = array.shape[0], 1
        array = array.reshape(fils,cols)
    else: # Multivariado
        fils, cols = array.shape

    # Generar los arreglos
    for i in range(fils-input_length-output_length):
        X.append(array[i:i+INPUT_LENGTH,0:cols])
        Y.append(array[i+input_length:i+input_length+output_length,-1].reshape(output_length,1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# %%
# Crear los datasets de entrenamiento, prueba y validación y verificar sus tamaños
INPUT_LENGTH = 24    # Posteriormente afinaremos este hiperparámetro
OUTPUT_LENGTH = 4    # Modelo uni-step

x_tr, y_tr = crear_dataset_supervisado(tr.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_vl, y_vl = crear_dataset_supervisado(vl.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_ts, y_ts = crear_dataset_supervisado(ts.values, INPUT_LENGTH, OUTPUT_LENGTH)

# Imprimir información en pantalla
print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Set de entrenamiento - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Set de validación - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Set de prueba - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Set de entrenamiento - x_tr: (15103, 24, 7), y_tr: (15103, 4, 1)
# Set de validación - x_vl: (1863, 24, 7), y_vl: (1863, 4, 1)
# Set de prueba - x_ts: (1864, 24, 7), y_ts: (1864, 4, 1)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
# atributo a predecir
col_ref = df.columns.get_loc("NO2")

NFEATS = x_tr.shape[2]
print("NFEATS = ", NFEATS)
print("col_ref=", col_ref)

#Generar una lista de 'scalers', 1 para cada atributo
#scalers = [MinMaxScaler(feature_range=(-1,1)) for i in range(NFEATS)]
scalers = [MinMaxScaler(feature_range=(0,1)) for i in range(NFEATS)]
#scalers = [RobustScaler() for i in range(NFEATS)]
#scalers = [StandardScaler() for i in range(NFEATS)]
# Out:
# NFEATS =  7
# col_ref= 3

# %%
# Arreglos que contendrán los datasets escalados
x_tr_s = np.zeros(x_tr.shape)
x_vl_s = np.zeros(x_vl.shape)
x_ts_s = np.zeros(x_ts.shape)
y_tr_s = np.zeros(y_tr.shape)
y_vl_s = np.zeros(y_vl.shape)
y_ts_s = np.zeros(y_ts.shape)

for i in range(NFEATS):
  x_tr_s[:,:,i] = scalers[i].fit_transform(x_tr[:,:,i])
  x_vl_s[:,:,i] = scalers[i].transform(x_vl[:,:,i])
  x_ts_s[:,:,i] = scalers[i].transform(x_ts[:,:,i])

# Escalamiento Ys
y_tr_s[:,:,0] = scalers[col_ref].fit_transform(y_tr[:,:,0])
y_vl_s[:,:,0] = scalers[col_ref].transform(y_vl[:,:,0])
y_ts_s[:,:,0] = scalers[col_ref].transform(y_ts[:,:,0])

# %%
# Gráfica tipo violín para ver la distribución de los valores
fig, ax = plt.subplots(figsize=(12,4))
for i in range(NFEATS):
  ax.violinplot(dataset = x_tr_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset = x_vl_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset = x_ts_s[:,:,i].flatten(), positions=[i])

ax.set_xticks(list(range(NFEATS)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale();

# %%
NFEATS
# Out:
# 7

# %%
# Observemos la variable temperatura
fig, ax = plt.subplots(figsize=(6,4))
ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())
ax.set_xticks([1])
ax.set_xticklabels(['y (salida)']);

# %%
# Creación del modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf

# Ajustar parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()

# El modelo

N_UNITS = 128  # Tamaño del estado oculto (h)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2]) # 24 (horas) x 13 (feature)

modelo = Sequential()
modelo.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE)) #, return_sequences=True))
#modelo.add(LSTM(64))
modelo.add(Dense(OUTPUT_LENGTH, activation='linear')) # activation = 'linear' pues queremos pronosticar (regresión)
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               69632
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 70148 (274.02 KB)
# Trainable params: 70148 (274.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Pérdida: se usará el RMSE (root mean squared error) para el entrenamiento
# pues permite tener errores en las mismas unidades de la temperatura
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# Compilación
optimizador = RMSprop(learning_rate=5e-4)
modelo.compile(
    optimizer = optimizador,
    loss=root_mean_squared_error  #loss = 'mse'
)

# Entrenamiento (aproximadamente 1 min usando GPU)
EPOCHS = 80 # Hiperparámetro
BATCH_SIZE = 256 # Hiperparámetro
historia = modelo.fit(
    x = x_tr_s,
    y = y_tr_s,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_vl_s, y_vl_s),
    verbose=2
)
# Out:
# Epoch 1/80
# 59/59 - 8s - loss: 0.1034 - val_loss: 0.0818 - 8s/epoch - 133ms/step
# Epoch 2/80
# 59/59 - 0s - loss: 0.0904 - val_loss: 0.0878 - 311ms/epoch - 5ms/step
# Epoch 3/80
# 59/59 - 0s - loss: 0.0858 - val_loss: 0.0765 - 262ms/epoch - 4ms/step
# Epoch 4/80
# 59/59 - 0s - loss: 0.0839 - val_loss: 0.0793 - 259ms/epoch - 4ms/step
# Epoch 5/80
# 59/59 - 0s - loss: 0.0825 - val_loss: 0.0743 - 260ms/epoch - 4ms/step
# Epoch 6/80
# 59/59 - 0s - loss: 0.0815 - val_loss: 0.0748 - 261ms/epoch - 4ms/step
# Epoch 7/80
# 59/59 - 0s - loss: 0.0807 - val_loss: 0.0759 - 244ms/epoch - 4ms/step
# Epoch 8/80
# 59/59 - 0s - loss: 0.0801 - val_loss: 0.0778 - 254ms/epoch - 4ms/step
# Epoch 9/80
# 59/59 - 0s - loss: 0.0796 - val_loss: 0.0726 - 247ms/epoch - 4ms/step
# Epoch 10/80
# 59/59 - 0s - loss: 0.0794 - val_loss: 0.0722 - 255ms/epoch - 4ms/step
# Epoch 11/80
# 59/59 - 0s - loss: 0.0790 - val_loss: 0.0717 - 247ms/epoch - 4ms/step
# Epoch 12/80
# 59/59 - 0s - loss: 0.0788 - val_loss: 0.0720 - 249ms/epoch - 4ms/step
# Epoch 13/80
# 59/59 - 0s - loss: 0.0787 - val_loss: 0.0717 - 251ms/epoch - 4ms/step
# Epoch 14/80
# 59/59 - 0s - loss: 0.0785 - val_loss: 0.0715 - 268ms/epoch - 5ms/step
# Epoch 15/80
# 59/59 - 0s - loss: 0.0784 - val_loss: 0.0728 - 244ms/epoch - 4ms/step
# Epoch 16/80
# 59/59 - 0s - loss: 0.0783 - val_loss: 0.0742 - 243ms/epoch - 4ms/step
# Epoch 17/80
# 59/59 - 0s - loss: 0.0782 - val_loss: 0.0724 - 250ms/epoch - 4ms/step
# Epoch 18/80
# 59/59 - 0s - loss: 0.0781 - val_loss: 0.0711 - 258ms/epoch - 4ms/step
# Epoch 19/80
# 59/59 - 0s - loss: 0.0780 - val_loss: 0.0710 - 249ms/epoch - 4ms/step
# Epoch 20/80
# 59/59 - 0s - loss: 0.0780 - val_loss: 0.0722 - 246ms/epoch - 4ms/step
# Epoch 21/80
# 59/59 - 0s - loss: 0.0779 - val_loss: 0.0712 - 246ms/epoch - 4ms/step
# Epoch 22/80
# 59/59 - 0s - loss: 0.0779 - val_loss: 0.0710 - 263ms/epoch - 4ms/step
# Epoch 23/80
# 59/59 - 0s - loss: 0.0778 - val_loss: 0.0716 - 251ms/epoch - 4ms/step
# Epoch 24/80
# 59/59 - 0s - loss: 0.0778 - val_loss: 0.0715 - 247ms/epoch - 4ms/step
# Epoch 25/80
# 59/59 - 0s - loss: 0.0778 - val_loss: 0.0716 - 278ms/epoch - 5ms/step
# Epoch 26/80
# 59/59 - 0s - loss: 0.0777 - val_loss: 0.0715 - 286ms/epoch - 5ms/step
# Epoch 27/80
# 59/59 - 0s - loss: 0.0777 - val_loss: 0.0711 - 269ms/epoch - 5ms/step
# Epoch 28/80
# 59/59 - 0s - loss: 0.0777 - val_loss: 0.0719 - 264ms/epoch - 4ms/step
# Epoch 29/80
# 59/59 - 0s - loss: 0.0777 - val_loss: 0.0712 - 302ms/epoch - 5ms/step
# Epoch 30/80
# 59/59 - 0s - loss: 0.0776 - val_loss: 0.0712 - 263ms/epoch - 4ms/step
# Epoch 31/80
# 59/59 - 0s - loss: 0.0775 - val_loss: 0.0714 - 258ms/epoch - 4ms/step
# Epoch 32/80
# 59/59 - 0s - loss: 0.0776 - val_loss: 0.0710 - 251ms/epoch - 4ms/step
# Epoch 33/80
# 59/59 - 0s - loss: 0.0776 - val_loss: 0.0722 - 256ms/epoch - 4ms/step
# Epoch 34/80
# 59/59 - 0s - loss: 0.0775 - val_loss: 0.0713 - 254ms/epoch - 4ms/step
# Epoch 35/80
# 59/59 - 0s - loss: 0.0775 - val_loss: 0.0711 - 256ms/epoch - 4ms/step
# Epoch 36/80
# 59/59 - 0s - loss: 0.0774 - val_loss: 0.0714 - 254ms/epoch - 4ms/step
# Epoch 37/80
# 59/59 - 0s - loss: 0.0775 - val_loss: 0.0726 - 257ms/epoch - 4ms/step
# Epoch 38/80
# 59/59 - 0s - loss: 0.0774 - val_loss: 0.0712 - 297ms/epoch - 5ms/step
# Epoch 39/80
# 59/59 - 0s - loss: 0.0774 - val_loss: 0.0717 - 347ms/epoch - 6ms/step
# Epoch 40/80
# 59/59 - 0s - loss: 0.0773 - val_loss: 0.0713 - 339ms/epoch - 6ms/step
# Epoch 41/80
# 59/59 - 0s - loss: 0.0773 - val_loss: 0.0723 - 325ms/epoch - 6ms/step
# Epoch 42/80
# 59/59 - 0s - loss: 0.0773 - val_loss: 0.0727 - 332ms/epoch - 6ms/step
# Epoch 43/80
# 59/59 - 1s - loss: 0.0772 - val_loss: 0.0716 - 545ms/epoch - 9ms/step
# Epoch 44/80
# 59/59 - 1s - loss: 0.0771 - val_loss: 0.0707 - 760ms/epoch - 13ms/step
# Epoch 45/80
# 59/59 - 0s - loss: 0.0772 - val_loss: 0.0722 - 475ms/epoch - 8ms/step
# Epoch 46/80
# 59/59 - 1s - loss: 0.0771 - val_loss: 0.0711 - 802ms/epoch - 14ms/step
# Epoch 47/80
# 59/59 - 0s - loss: 0.0771 - val_loss: 0.0718 - 383ms/epoch - 6ms/step
# Epoch 48/80
# 59/59 - 0s - loss: 0.0770 - val_loss: 0.0709 - 276ms/epoch - 5ms/step
# Epoch 49/80
# 59/59 - 1s - loss: 0.0770 - val_loss: 0.0708 - 624ms/epoch - 11ms/step
# Epoch 50/80
# 59/59 - 0s - loss: 0.0769 - val_loss: 0.0718 - 279ms/epoch - 5ms/step
# Epoch 51/80
# 59/59 - 0s - loss: 0.0769 - val_loss: 0.0722 - 242ms/epoch - 4ms/step
# Epoch 52/80
# 59/59 - 0s - loss: 0.0768 - val_loss: 0.0709 - 260ms/epoch - 4ms/step
# Epoch 53/80
# 59/59 - 0s - loss: 0.0768 - val_loss: 0.0716 - 251ms/epoch - 4ms/step
# Epoch 54/80
# 59/59 - 0s - loss: 0.0768 - val_loss: 0.0715 - 250ms/epoch - 4ms/step
# Epoch 55/80
# 59/59 - 0s - loss: 0.0767 - val_loss: 0.0708 - 246ms/epoch - 4ms/step
# Epoch 56/80
# 59/59 - 0s - loss: 0.0767 - val_loss: 0.0716 - 259ms/epoch - 4ms/step
# Epoch 57/80
# 59/59 - 0s - loss: 0.0766 - val_loss: 0.0719 - 266ms/epoch - 5ms/step
# Epoch 58/80
# 59/59 - 0s - loss: 0.0767 - val_loss: 0.0725 - 253ms/epoch - 4ms/step
# Epoch 59/80
# 59/59 - 0s - loss: 0.0766 - val_loss: 0.0726 - 250ms/epoch - 4ms/step
# Epoch 60/80
# 59/59 - 0s - loss: 0.0765 - val_loss: 0.0713 - 252ms/epoch - 4ms/step
# Epoch 61/80
# 59/59 - 0s - loss: 0.0766 - val_loss: 0.0724 - 247ms/epoch - 4ms/step
# Epoch 62/80
# 59/59 - 0s - loss: 0.0765 - val_loss: 0.0710 - 270ms/epoch - 5ms/step
# Epoch 63/80
# 59/59 - 0s - loss: 0.0765 - val_loss: 0.0718 - 260ms/epoch - 4ms/step
# Epoch 64/80
# 59/59 - 0s - loss: 0.0764 - val_loss: 0.0715 - 247ms/epoch - 4ms/step
# Epoch 65/80
# 59/59 - 0s - loss: 0.0763 - val_loss: 0.0725 - 346ms/epoch - 6ms/step
# Epoch 66/80
# 59/59 - 0s - loss: 0.0763 - val_loss: 0.0713 - 300ms/epoch - 5ms/step
# Epoch 67/80
# 59/59 - 0s - loss: 0.0763 - val_loss: 0.0712 - 257ms/epoch - 4ms/step
# Epoch 68/80
# 59/59 - 0s - loss: 0.0763 - val_loss: 0.0716 - 251ms/epoch - 4ms/step
# Epoch 69/80
# 59/59 - 0s - loss: 0.0763 - val_loss: 0.0719 - 257ms/epoch - 4ms/step
# Epoch 70/80
# 59/59 - 0s - loss: 0.0761 - val_loss: 0.0708 - 249ms/epoch - 4ms/step
# Epoch 71/80
# 59/59 - 0s - loss: 0.0762 - val_loss: 0.0717 - 262ms/epoch - 4ms/step
# Epoch 72/80
# 59/59 - 0s - loss: 0.0761 - val_loss: 0.0710 - 255ms/epoch - 4ms/step
# Epoch 73/80
# 59/59 - 0s - loss: 0.0761 - val_loss: 0.0717 - 250ms/epoch - 4ms/step
# Epoch 74/80
# 59/59 - 0s - loss: 0.0760 - val_loss: 0.0727 - 246ms/epoch - 4ms/step
# Epoch 75/80
# 59/59 - 0s - loss: 0.0760 - val_loss: 0.0712 - 262ms/epoch - 4ms/step
# Epoch 76/80
# 59/59 - 0s - loss: 0.0760 - val_loss: 0.0727 - 252ms/epoch - 4ms/step
# Epoch 77/80
# 59/59 - 0s - loss: 0.0760 - val_loss: 0.0720 - 256ms/epoch - 4ms/step
# Epoch 78/80
# 59/59 - 0s - loss: 0.0759 - val_loss: 0.0716 - 247ms/epoch - 4ms/step
# Epoch 79/80
# 59/59 - 0s - loss: 0.0759 - val_loss: 0.0725 - 264ms/epoch - 4ms/step
# Epoch 80/80
# 59/59 - 0s - loss: 0.0758 - val_loss: 0.0713 - 254ms/epoch - 4ms/step

# %%
 # Graficar curvas de entrenamiento y validación
 # para verificar que no existe overfitting
plt.plot(historia.history['loss'],label='RMSE train')
plt.plot(historia.history['val_loss'],label='RMSE val')
plt.xlabel('Iteración')
plt.ylabel('RMSE')
plt.legend();

# %% [markdown]
# ### Desempeño del modelo

# %%
# Cálculo de MSE para train, val y test
Rmse_tr = modelo.evaluate(x=x_tr_s, y=y_tr_s, verbose=0)
Rmse_vl = modelo.evaluate(x=x_vl_s, y=y_vl_s, verbose=0)
Rmse_ts = modelo.evaluate(x=x_ts_s, y=y_ts_s, verbose=0)

# Imprimir resultados en pantalla
print('Comparativo desempeños:')
print(f'  MSE train:\t {Rmse_tr:.3f}')
print(f'  MSE val:\t {Rmse_vl:.3f}')
print(f'  MSE test:\t {Rmse_ts:.3f}')
# Out:
# Comparativo desempeños:
#   MSE train:	 0.071
#   MSE val:	 0.068
#   MSE test:	 0.073

# %%
# analizando RMSE en cada una de las 4 predicciones de temperatura
# Calcular predicción sobre el set de prueba escalada en el rango de -1 a 1
y_ts_pred_s = modelo.predict(x_ts_s,verbose=0)

# Llevar la predicción a la escala original
y_ts_pred = scalers[col_ref].inverse_transform(y_ts_pred_s)

# calcular RMSE para cada instante de tiempo predicho
diff_cuad = np.square(y_ts.squeeze()-y_ts_pred)
proms = np.mean(diff_cuad, axis=0) # 1x4
rmse = np.sqrt(proms) # 1x4

#Graficar RMSE
t = np.linspace(1,4,4)

fig,ax = plt.subplots()
ax.scatter(t, rmse)
ax.set_xlabel("Hora predicha")
ax.set_ylabel("Error RMSE (oC)")
plt.xticks(ticks=t, labels=t)
plt.grid();

# %%
def predecir(x, model, scaler):
    '''Genera la predicción de OUTPUT_LENGTH instantes
    de tiempo a futuro con el modelo entrenado.

    Entrada:
    - x: batch (o batches) de datos para ingresar al modelo
      (tamaño: BATCHES X INPUT_LENGTH X FEATURES)
    - model: Red LSTM entrenada
    - scaler: escalador (requerido para llevar la predicción a la escala original)

    Salida:
    - y_pred: la predicción en la escala original (tamaño: BATCHES X OUTPUT_LENGTH X FEATURES)
    '''

    # Calcular predicción escalada en el rango de -1 a 1
    y_pred_s = model.predict(x,verbose=0)

    # Llevar la predicción a la escala original
    y_pred = scaler.inverse_transform(y_pred_s)

    return y_pred.flatten()

# %%
# Calcular predicciones sobre el set de prueba
y_ts_pred = predecir(x_ts_s, modelo, scalers[col_ref])

# %%
N = len(y_ts_pred)    # Número de predicciones
ndato = np.linspace(1,N,N)

# Cálculo de errores simples
errores = y_ts.flatten()-y_ts_pred
plt.plot(errores);
